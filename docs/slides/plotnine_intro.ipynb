# %% [markdown]
# # Plotting with the grammar of graphics
#
# Peter Ralph
# 2026-01-12
#
# # A classic example
#
# Let’s get things set up:

# %%
import pandas as pd
import plotnine as p9

# %% [markdown]
# and use the [Palmer
# Penguins](https://allisonhorst.github.io/palmerpenguins/articles/intro.html)
# dataset

# %%
from plotnine.data import penguins

# %% [markdown]
# ## the data

# %%
penguins

# %% [markdown]
# ## the data, v2

# %%
pd.crosstab(penguins.species,  penguins.island)

# %% [markdown]
# ## Let’s make some plots!

# %%
(
    p9.ggplot(penguins,
        p9.aes(x='flipper_length_mm', y='body_mass_g', color='species')
    ) + p9.geom_point()
)

# %% [markdown]
# ## What’s going on there?
#
# [plotnine](https://plotnine.org/guide/introduction.html) is basically a
# port of [ggplot2](https://ggplot2.tidyverse.org/) for python.
#
# Have a look at the
# [cheatsheet](https://github.com/rstudio/cheatsheets/blob/main/plotnine.pdf):
#
#     ggplot(
#         data,
#         aes(...)
#     ) + geom_function()
#
# or, with all the bells and whistles:
#
#     ggplot(data=data_frame)
#     + geom_function(
#       mapping=aes(**mappings)
#       stat=stat,
#       position=position,
#     ) + coord_function()
#     + facet_function()
#     + scale_function()
#     + theme_function()
#     + theme(**settings)
#
# ## Let’s try it out!
#
# # YTS data
#
# Here’s some summarized [data from the YTS](data/yts_summarized.csv):

# %%
yts = pd.read_csv("data/yts_summarized.csv")
yts
